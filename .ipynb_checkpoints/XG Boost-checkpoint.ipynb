# %% [markdown]
# >Xgboost process data in its own format i.e.Dmatrix<br>
# >CatBoot(Categorical Boosting) from company Yandex<br>
# >>cat boost works withput hot encoding(without creating dummies)

# %%
from xgboost import XGBClassifier

# %%
import pandas as pd
import numpy as np

# %%
hr = pd.read_csv("/Users/darshmac/Documents/cdac/For DBDA/PML/Cases/human-resources-analytics/HR_comma_sep.csv")
hr
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.10             0.77               6
# 3                    0.92             0.85               5
# 4                    0.89             1.00               5
# ...                   ...              ...             ...
# 14990                0.40             0.57               2
# 14991                0.37             0.48               2
# 14992                0.37             0.53               2
# 14993                0.11             0.96               6
# 14994                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       247                   4              0     1
# 3                       259                   5              0     1
# 4                       224                   5              0     1
# ...                     ...                 ...            ...   ...
# 14990                   151                   3              0     1
# 14991                   160                   3              0     1
# 14992                   143                   3              0     1
# 14993                   280                   4              0     1
# 14994                   158                   3              0     1
#
#        promotion_last_5years Department  salary
# 0                          0      sales     low
# 1                          0      sales  medium
# 2                          0      sales     low
# 3                          0      sales     low
# 4                          0      sales     low
# ...                      ...        ...     ...
# 14990                      0    support     low
# 14991                      0    support     low
# 14992                      0    support     low
# 14993                      0    support     low
# 14994                      0    support     low
#
# [14995 rows x 10 columns]

# %%
dum_hr = pd.get_dummies(hr,drop_first=True)
X = dum_hr.drop('left',axis=1)
y = dum_hr['left']

# %%
from sklearn.model_selection import StratifiedKFold,GridSearchCV,train_test_split

# %%
kflod = StratifiedKFold(n_splits=5, shuffle=True,random_state=23)

# %%
xgbc = XGBClassifier(random_state=23)

# %%
xgparam = {'n_estimators':[25,50,75,100]}
xgbgcv = GridSearchCV(xgbc,param_grid=xgparam,cv=kflod,verbose=3,scoring='neg_log_loss')

# %%
# %%time
xgbgcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END ..................n_estimators=25;, score=-0.076 total time=   0.1s
# [CV 2/5] END ..................n_estimators=25;, score=-0.068 total time=   0.1s
# [CV 3/5] END ..................n_estimators=25;, score=-0.062 total time=   0.1s
# [CV 4/5] END ..................n_estimators=25;, score=-0.070 total time=   0.1s
# [CV 5/5] END ..................n_estimators=25;, score=-0.068 total time=   0.1s
# [CV 1/5] END ..................n_estimators=50;, score=-0.065 total time=   0.1s
# [CV 2/5] END ..................n_estimators=50;, score=-0.059 total time=   0.1s
# [CV 3/5] END ..................n_estimators=50;, score=-0.051 total time=   0.1s
# [CV 4/5] END ..................n_estimators=50;, score=-0.059 total time=   0.1s
# [CV 5/5] END ..................n_estimators=50;, score=-0.060 total time=   0.1s
# [CV 1/5] END ..................n_estimators=75;, score=-0.061 total time=   0.2s
# [CV 2/5] END ..................n_estimators=75;, score=-0.054 total time=   0.1s
# [CV 3/5] END ..................n_estimators=75;, score=-0.049 total time=   0.2s
# [CV 4/5] END ..................n_estimators=75;, score=-0.051 total time=   0.2s
# [CV 5/5] END ..................n_estimators=75;, score=-0.057 total time=   0.2s
# [CV 1/5] END .................n_estimators=100;, score=-0.058 total time=   0.2s
# [CV 2/5] END .................n_estimators=100;, score=-0.050 total time=   0.2s
# [CV 3/5] END .................n_estimators=100;, score=-0.047 total time=   0.2s
# [CV 4/5] END .................n_estimators=100;, score=-0.047 total time=   0.2s
# [CV 5/5] END .................n_estimators=100;, score=-0.055 total time=   0.2s
# CPU times: user 18.9 s, sys: 1.38 s, total: 20.3 s
# Wall time: 2.87 s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_typ...
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=23, ...),
#              param_grid={'n_estimators': [25, 50, 75, 100]},
#              scoring='neg_log_loss', verbose=3)

# %%
print(xgbgcv.best_params_)
print(xgbgcv.best_score_)
# Out:
# {'n_estimators': 100}
# -0.05147130380312329

# %%
#For Boston
bos = pd.read_csv("/Users/darshmac/Documents/cdac/For DBDA/PML/Cases/Boston Housing/Boston.csv")
bos
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
X = bos.drop('medv', axis =1)
y = bos['medv']

# %%
from xgboost import XGBRegressor
xgbr = XGBRegressor(random_state=23)

# %%
from sklearn.model_selection import KFold
rkfold = KFold(n_splits=5,shuffle=True,random_state=23)

# %%
xgbrparam = {'n_estimators':[25,50,75,100],
             'learning_rate':np.linspace(0.001,0.7,5),
             'max_depth':[None,2,3,5]}
xgbrgcv = GridSearchCV(xgbr,param_grid=xgbrparam,cv=rkfold)

# %%
# %%time
xgbrgcv.fit(X,y)
# Out:
# CPU times: user 15.1 s, sys: 804 ms, total: 15.9 s
# Wall time: 2.23 s
# GridSearchCV(cv=KFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=23, ...),
#              param_grid={'n_estimators': [25, 50, 75, 100]})

# %%
print(xgbrgcv.best_params_)
print(xgbrgcv.best_score_)
# Out:
# {'n_estimators': 50}
# 0.8722404308722386
